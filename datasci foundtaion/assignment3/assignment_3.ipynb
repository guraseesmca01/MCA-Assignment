# %%
student = (101, "Palika", 9.1)
print(student)
# Out:
# (101, 'Palika', 9.1)

# %%
a = tuple(map(int, input("Enter 6 integers: ").split()))
print(a[::-1])
# Out:
# Enter 6 integers:  1 2 3 4 5 6
# (6, 5, 4, 3, 2, 1)

# %%
t = (10, 20, 30, 40, 50, 60)

print(t[1:-1])
# Out:
# (20, 30, 40, 50)

# %%
t1 = (1, 2, 3)
t2 = (4, 5)

t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4, 5)

# %%
t = (1, 3, 5)

print(t * 3)
# Out:
# (1, 3, 5, 1, 3, 5, 1, 3, 5)

# %%
t = (10, 15, 20, 25, 30)

n = int(input("Enter number: "))

print(n in t)
# Out:
# Enter number:  15
# True

# %%
t = tuple(map(int, input("Enter tuple elements: ").split()))
n = int(input("Enter value: "))

print(t.count(n))
# Out:
# Enter tuple elements:  1 2 3 2 4 2
# Enter value:  2
# 3

# %%
t = tuple(map(int, input("Enter tuple elements: ").split()))
n = int(input("Enter value: "))

print(t.index(n))
# Out:
# Enter tuple elements:  5 10 15 20
# Enter value:  15
# 2

# %%
t = tuple(map(int, input("Enter numbers: ").split()))

print("Max =", max(t))
print("Min =", min(t))
# Out:
# Enter numbers:  8 3 9 1 6
# Max = 9
# Min = 1

# %%
t = tuple(map(int, input("Enter numbers: ").split()))

print(sum(t))
# Out:
# Enter numbers:  2 4 6 8
# 20

# %%
s = input("Enter a string: ")

t = tuple(s)

print(t)
# Out:
# Enter a string:  computer
# ('c', 'o', 'm', 'p', 'u', 't', 'e', 'r')

# %%
l = [11, 22, 33, 44]

t = tuple(l)

print(t)
print(type(t))
# Out:
# (11, 22, 33, 44)
# <class 'tuple'>

# %%
t = tuple(map(int, input("Enter numbers: ").split()))

print(sorted(t))
# Out:
# Enter numbers:  9 3 7 1 5
# [1, 3, 5, 7, 9]

# %%
t = tuple(map(int, input("Enter numbers: ").split()))

print(len(t))
# Out:
# Enter numbers:  10 20 30
# 3

# %%
t = (2, 4, 6, 8, 10)

result = all(x % 2 == 0 for x in t)

print(result)
# Out:
# True

# %%
students = {
    "Aman": 78,
    "Riya": 85,
    "Kabir": 69,
    "Neha": 90,
    "Arjun": 74
}

print("Keys:", list(students.keys()))
print("Values:", list(students.values()))
# Out:
# Keys: ['Aman', 'Riya', 'Kabir', 'Neha', 'Arjun']
# Values: [78, 85, 69, 90, 74]

# %%
students = {
    "Aman": 78,
    "Riya": 85,
    "Kabir": 69,
    "Neha": 90,
    "Arjun": 74
}

name = input("Enter name: ")

if name in students:
    print("Key found. Value =", students[name])
else:
    print("Key not found.")
# Out:
# Enter name:  Aman
# Key found. Value = 78

# %%
d1 = {1: 'A', 2: 'B'}
d2 = {3: 'C', 4: 'D'}

d1.update(d2)

print("Merged Dictionary:", d1)
# Out:
# Merged Dictionary: {1: 'A', 2: 'B', 3: 'C', 4: 'D'}

# %%
fruits = {
    "Apple": 100,
    "Banana": 40,
    "Mango": 60
}

fruit = input("Enter fruit: ")
price = int(input("Enter new price: "))

fruits[fruit] = price

print("Updated Dictionary:", fruits)
# Out:
# Enter fruit:  Apple
# Enter new price:  110
# Updated Dictionary: {'Apple': 110, 'Banana': 40, 'Mango': 60}

# %%
fruits = {
    "Apple": 120,
    "Banana": 40,
    "Mango": 60
}

key = input("Enter key to delete: ")

del fruits[key]

print("Updated Dictionary:", fruits)
# Out:
# Enter key to delete:  Apple
# Updated Dictionary: {'Banana': 40, 'Mango': 60}

# %%
d = {
    "Apple": 120,
    "Banana": 40,
    "Mango": 60
}

print("Total keys =", len(d))
# Out:
# Total keys = 3

# %%
students = {
    101: "Amit",
    102: "Neha",
    103: "Rahul"
}

for id, name in students.items():
    print(id, "->", name)
# Out:
# 101 -> Amit
# 102 -> Neha
# 103 -> Rahul

# %%
marks = {
    "Maths": 95,
    "Science": 88,
    "English": 90
}

subject = max(marks, key=marks.get)

print("Highest Marks Subject:", subject, "=", marks[subject])
# Out:
# Highest Marks Subject: Maths = 95

# %%
keys = [1, 2, 3]
values = ['A', 'B', 'C']

d = dict(zip(keys, values))

print(d)
# Out:
# {1: 'A', 2: 'B', 3: 'C'}

# %%
d1 = {
    1: 10,
    2: 20
}

d2 = d1.copy()

print("Original:", d1)
print("Copied:", d2)
# Out:
# Original: {1: 10, 2: 20}
# Copied: {1: 10, 2: 20}

# %%
d = {
    "A": 80,
    "B": 90,
    "C": 70
}

value = int(input("Enter value: "))

if value in d.values():
    print("Value exists")
else:
    print("Value does not exist")
# Out:
# Enter value:  90
# Value exists

# %%
d = {
    1: 10,
    2: 20,
    3: 30
}

d.popitem()

print("Updated Dictionary after removing last item:", d)
# Out:
# Updated Dictionary after removing last item: {1: 10, 2: 20}

# %%
items = {
    "Pen": 10,
    "Pencil": 20
}

item = input("Enter item: ")

items[item] = items[item] + 5

print("Updated Dictionary:", items)
# Out:
# Enter item:  Pen
# Updated Dictionary: {'Pen': 15, 'Pencil': 20}

# %%
items = {
    "Pen": 15,
    "Pencil": 20
}

for key, value in items.items():
    print(key, ":", value)
# Out:
# Pen : 15
# Pencil : 20

# %%
d = {
    1: 10,
    2: 20,
    3: 30
}

d.clear()

print("Dictionary after clear:", d)
# Out:
# Dictionary after clear: {}

# %%
d = {}

for i in range(1, 6):
    d[i] = i * i

print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
ages = {
    "Aman": 20,
    "Riya": 22,
    "Neha": 21
}

name = input("Enter name: ")

print("Age =", ages[name])
# Out:
# Enter name:  Neha
# Age = 21

# %%
d = {}

for i in range(3):
    key = input("Enter key: ")
    value = int(input("Enter value: "))
    d[key] = value

print(d)
# Out:
# Enter key:  A
# Enter value:  10
# Enter key:  B
# Enter value:  20
# Enter key:  C
# Enter value:  30
# {'A': 10, 'B': 20, 'C': 30}

# %%
capitals = {
    "India": "Delhi",
    "Japan": "Tokyo",
    "France": "Paris"
}

for capital in capitals.values():
    print(capital)
# Out:
# Delhi
# Tokyo
# Paris

# %%
d = {
    "A": 40,
    "B": 70,
    "C": 80,
    "D": 30
}

count = 0

for value in d.values():
    if value > 50:
        count += 1

print("Count =", count)
# Out:
# Count = 2

# %%
numbers = set(map(int, input("Enter numbers: ").split()))

print(numbers)
# Out:
# Enter numbers:  1 2 2 3 4 4
# {1, 2, 3, 4}

# %%
s = {10, 5.5, "Hello"}

print(s)
print("Length =", len(s))
# Out:
# {10, 5.5, 'Hello'}
# Length = 3

# %%
cities = ["Delhi", "Patiala", "Delhi", "Amritsar", "Patiala"]

s = set(cities)

print(s)
# Out:
# {'Delhi', 'Amritsar', 'Patiala'}

# %%
s = set()

for i in range(3):
    value = input("Enter element: ")
    s.add(value)

print(s)
# Out:
# Enter element:  2
# Enter element:  123
# Enter element:  45
# {'123', '2', '45'}

# %%
s = {2, 4, 6}

n = int(input("Enter new number: "))

s.add(n)

print(s)
# Out:
# Enter new number:  8
# {8, 2, 4, 6}

# %%
s = {1, 2, 3}

t = (4, 5, 6)

s.update(t)

print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s = {"A", "B"}

text = input("Enter a string: ")

s.update(text)

print(s)
# Out:
# Enter a string:  student
# {'B', 'n', 'A', 'u', 's', 'd', 't', 'e'}

# %%
A = {1, 2, 3}
B = {3, 4, 5}

A.update(B)

print(A)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {10, 20, 30, 40}

n = int(input("Enter element to delete: "))

s.discard(n)

print(s)
# Out:
# Enter element to delete:  30
# {40, 10, 20}

# %%
s = {3, 7, 10, 15, 2, 20}

s = {x for x in s if x >= 10}

print(s)
# Out:
# {10, 20, 15}

# %%
languages = {"Python", "C", "C++", "Java", "JavaScript"}

word = input("Enter programming language: ")

if word in languages:
    print("Language exists")
else:
    print("Language does not exist")
# Out:
# Enter programming language:  C
# Language exists

# %%
s = {1, 3, 5, 6, 8, 9, 10, 12}

s = {x for x in s if x % 3 != 0}

print(s)
# Out:
# {8, 1, 10, 5}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
print("Symmetric Difference:", A ^ B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 5, 6}

# %%
math = {"Aman", "Riya", "Neha", "Rahul"}
physics = {"Neha", "Rahul", "Karan", "Simran"}

both = math & physics

print("Students in both:", both)
# Out:
# Students in both: {'Rahul', 'Neha'}

# %%
math = {101, 102, 103, 104}
physics = {103, 104, 105, 106}

result = math ^ physics

print("Students in exactly one course:", result)
# Out:
# Students in exactly one course: {101, 102, 105, 106}

# %%
A = {1, 2, 3}
B = {4, 5, 6}

if A.isdisjoint(B):
    print("No common elements")
else:
    print("Common elements exist")
# Out:
# No common elements

# %%
A = {1, 2}
B = {1, 2, 3, 4}

print("A is subset of B:", A.issubset(B))
print("A is superset of B:", A.issuperset(B))
# Out:
# A is subset of B: True
# A is superset of B: False

# %%
sentence = input("Enter a sentence: ")

s = set(sentence.replace(" ", ""))

print(s)
# Out:
# Enter a sentence:  hello world
# {'r', 'l', 'e', 'h', 'w', 'd', 'o'}
